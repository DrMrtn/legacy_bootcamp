# %%
# !jt -t onedork -tf hack -f fira -fs 95 -tfs 11 -nfs 115 -cellw 88% -T

# %%
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import requests
import pandas as pd
import re
import random

# %%
url = '#############'

# %%
response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <script>
#                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                 })(window, document, 'script', 'dataLayer', 'GTM-KNKC2R');
#         </script>
# <title>
# Certified Top Employers Search    </title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta name="description"/>
# <meta name="keywords"/>
# <meta content="Certified Top Employers Search" property="og:title"/>
# ...

# %%
soup.select('h3.company-item__title')
soup.select('li.tag.tag--country')
soup.select('li.tag.tag--region')
# Out:
# [<li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">NL</li>,
#  <li class="tag tag--country">AE</li>,
#  <li class="tag tag--country">AE</li>,
#  <li class="tag tag--country">ES</li>,
#  <li class="tag tag--country">IT</li>,
#  <li class="tag tag--country">AO</li>,
#  <li class="tag tag--country">AT</li>,
#  <li class="tag tag--country">AU</li>,
#  <li class="tag tag--country">AU</li>,
#  <li class="tag tag--country">AU</li>,
#  <li class="tag tag--country">BE</li>,
# ...

# %%
c = soup.select('h3.company-item__title')
d = soup.select('li.tag')
comp = []
reg = []
con = []
t = {'company':comp,'region':reg,'country':con}
# for i in range(len(soup.select('h3.company-item__title'))):
#     comp.append(c[i].get_text())
# for i in range(len(soup.select('li.tag.tag--country'))):
#     con.append(c[i].get_text())
# for i in range(len(soup.select('li.tag.tag--region'))):
#     reg.append(c[i].get_text())

# %%
# !pip install bs4 selenium

# %%
# import webdriver
from selenium import webdriver 
import re

# %%
from selenium import webdriver

from selenium.webdriver.chrome.service import Service

chromedriver = ""

option = webdriver.ChromeOptions()

option.binary_location = ""

s = Service(chromedriver)

driver = webdriver.Firefox(service=s)

driver.get("https://google.com")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [21], in <cell line: 13>()
#       9 option.binary_location = "/home/gladius/snap/brave/170/opt/brave.com/brave/brave-browser"
#      11 s = Service(chromedriver)
# ---> 13 driver = webdriver.Firefox(service=s)
#      15 driver.get("https://google.com")
#
# File ~/anaconda3/lib/python3.9/site-packages/selenium/webdriver/firefox/webdriver.py:177, in WebDriver.__init__(self, firefox_profile, firefox_binary, capabilities, proxy, executable_path, options, service_log_path, service_args, service, desired_capabilities, log_path, keep_alive)
#     172 self.service.start()
#     174 executor = FirefoxRemoteConnection(
#     175     remote_server_addr=self.service.service_url,
#     176     ignore_proxy=options._ignore_local_proxy)
# --> 177 super().__init__(
#     178     command_executor=executor,
#     179     options=options,
# ...
